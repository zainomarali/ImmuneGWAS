# %%
from helpers.getpaths import *
from helpers.ldlink import *

# %%
import os 
import pandas as pd


# we only want a subset of the eqtl catalogue files, I have handpicked these to focus on immune and blood cell types

paths = get_paths(root="/media/")

all_files = os.listdir(paths['eqtl_cat'] + 'credible_sets')

meta = [i for i in os.listdir(paths['eqtl_cat']) if i.split(".")[-1]=="csv"]
meta = paths['eqtl_cat'] + meta[0]
meta = pd.read_csv(meta).Study.tolist()

files = []

for i in all_files:
    for m in meta:
        if m in i:
            files.append(paths['eqtl_cat']+'credible_sets/' + i)
            

# copy these files to a separate folder for further processing
            

out_dir = "/media/cbio3/data/eQTL_DB/curated_crediblesets/"

for path in files:
    name = path.split("/")[-1]
    out_path = out_dir + name
    command = "cp " + path + " " + out_path
    os.system(command)

# %% [markdown]
# We would like to tabix index these files - unfortunately they are not sorted. So I do the following:
#
#     1) unzip all the files using gunzip
#     2) sort each by chromosome and position
#     3) bgzip all the files
#     4) run tabix on the bgzipped files

# %%
# all files have been gunzipped, now sort using pandas 

sort_dict = {}

for i in range(23):
    sort_dict[str(i)] = i
    
sort_dict['X'] = 23

files = [out_dir + i for i in os.listdir(out_dir)]

# %%
# sort all the files 

for file in files:

    x = pd.read_csv(file, sep='\t')
    x.chromosome = x.chromosome.astype(str)
    x['int_chrom'] = x.chromosome.map(sort_dict)
    x = x.sort_values(by=['int_chrom', 'position'])
    x.to_csv(file, sep='\t', index=False)

# %%
# check that files were sorted

pd.read_csv(files[1], sep='\t').head()
# Out:
#   molecular_trait_id                                    variant chromosome  \
# 0    ENST00000304952                            chr1_989148_C_A          1
# 1    ENST00000428771                            chr1_989148_C_A          1
# 2    ENST00000304952  chr1_992967_GGGAGGGTCCATGTGTCCGTCATCTGA_G          1
# 3    ENST00000428771  chr1_992967_GGGAGGGTCCATGTGTCCGTCATCTGA_G          1
# 4    ENST00000304952                            chr1_999842_C_A          1
#
#    position                          ref alt               cs_id cs_index  \
# 0    989148                            C   A  ENST00000304952_L1       L1
# 1    989148                            C   A  ENST00000428771_L1       L1
# 2    992967  GGGAGGGTCCATGTGTCCGTCATCTGA   G  ENST00000304952_L1       L1
# 3    992967  GGGAGGGTCCATGTGTCCGTCATCTGA   G  ENST00000428771_L1       L1
# 4    999842                            C   A  ENST00000304952_L1       L1
#
#   finemapped_region       pip          z  cs_min_r2  cs_avg_r2  cs_size  \
# 0  chr1:172-2000172  0.088759 -11.038267   0.794414   0.908261       10
# 1  chr1:172-2000172  0.224966  13.740977   0.995728   0.997834        3
# 2  chr1:172-2000172  0.048185 -10.903157   0.794414   0.908261       10
# 3  chr1:172-2000172  0.248802  13.781570   0.995728   0.997834        3
# 4  chr1:172-2000172  0.254610 -11.276897   0.794414   0.908261       10
#
#    posterior_mean  posterior_sd  cs_log10bf  int_chrom
# 0       -0.078922      0.254003   23.243713          1
# 1        0.276131      0.516782   40.848565          1
# 2       -0.042205      0.188385   23.243713          1
# 3        0.302779      0.530263   40.848565          1
# 4       -0.224410      0.386022   23.243713          1

# %%
# gzip files for tabix
for file in files:
    command = "bgzip " + file
    os.system(command)

# %%
os.listdir(paths['eqtl_cat']+ '/curated_crediblesets')
# Out:
# ['Nedelec_2016_tx_macrophage_naive.purity_filtered.txt',
#  'Schmiedel_2018_exon_monocyte_naive.purity_filtered.txt',
#  'Schmiedel_2018_ge_Treg_naive.purity_filtered.txt',
#  'Nedelec_2016_tx_macrophage_naive.purity_filtered.txt.gz',
#  'Alasoo_2018_exon_macrophage_IFNg+Salmonella.purity_filtered.txt.gz',
#  'Quach_2016_ge_monocyte_R848.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_CD8_T-cell_naive.purity_filtered.txt.gz',
#  'Nedelec_2016_tx_macrophage_Listeria.purity_filtered.txt.gz',
#  'Alasoo_2018_ge_macrophage_IFNg+Salmonella.purity_filtered.txt.gz',
#  'BLUEPRINT_SE_ge_neutrophil.purity_filtered.txt',
#  'Nedelec_2016_txrev_macrophage_Listeria.purity_filtered.txt.gz',
#  'Alasoo_2018_exon_macrophage_IFNg+Salmonella.purity_filtered.txt',
#  'Alasoo_2018_tx_macrophage_naive.purity_filtered.txt',
#  'BLUEPRINT_SE_txrev_neutrophil.purity_filtered.txt',
#  'Bossini-Castillo_2019_exon_Treg_naive.purity_filtered.txt.gz',
#  'GENCORD_ge_fibroblast.purity_filtered.txt.gz',
#  'CEDAR_microarray_monocyte_CD14.purity_filtered.txt.gz',
#  'Bossini-Castillo_2019_ge_Treg_naive.purity_filtered.txt.gz',
#  'Quach_2016_tx_monocyte_Pam3CSK4.purity_filtered.txt.gz',
#  'Nedelec_2016_txrev_macrophage_Salmonella.purity_filtered.txt.gz',
#  'Quach_2016_tx_monocyte_LPS.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_NK-cell_naive.purity_filtered.txt.gz',
#  'Quach_2016_ge_monocyte_Pam3CSK4.purity_filtered.txt.gz',
#  'Schmiedel_2018_exon_CD4_T-cell_anti-CD3-CD28.purity_filtered.txt.gz',
#  'Quach_2016_exon_monocyte_IAV.purity_filtered.txt.gz.tbi',
#  'BLUEPRINT_SE_tx_monocyte.purity_filtered.txt.gz.tbi',
#  'Quach_2016_tx_monocyte_naive.purity_filtered.txt.gz.tbi',
#  'BLUEPRINT_SE_ge_monocyte.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_Th1-17_memory.purity_filtered.txt.gz.tbi',
#  'Fairfax_2014_microarray_monocyte_IFN24.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_monocyte_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_Th2_memory.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_Th2_memory.purity_filtered.txt.gz.tbi',
#  'GENCORD_exon_T-cell.purity_filtered.txt',
#  'CEDAR_microarray_neutrophil_CD15.purity_filtered.txt',
#  'GENCORD_txrev_T-cell.purity_filtered.txt',
#  'Nedelec_2016_ge_macrophage_Salmonella.purity_filtered.txt',
#  'Quach_2016_exon_monocyte_IAV.purity_filtered.txt',
#  'Quach_2016_ge_monocyte_R848.purity_filtered.txt',
#  'Schmiedel_2018_exon_CD4_T-cell_naive.purity_filtered.txt',
#  'Schmiedel_2018_tx_Th2_memory.purity_filtered.txt',
#  'Schmiedel_2018_txrev_Th17_memory.purity_filtered.txt',
#  'BLUEPRINT_PE_exon_T-cell.purity_filtered.txt',
#  'Schmiedel_2018_exon_Th17_memory.purity_filtered.txt',
#  'Fairfax_2014_microarray_monocyte_naive.purity_filtered.txt',
#  'Kasela_2017_microarray_T-cell_CD8.purity_filtered.txt',
#  'Schmiedel_2018_exon_monocyte_CD16_naive.purity_filtered.txt',
#  'Schmiedel_2018_txrev_CD4_T-cell_naive.purity_filtered.txt',
#  'Alasoo_2018_txrev_macrophage_IFNg+Salmonella.purity_filtered.txt',
#  'BLUEPRINT_PE_ge_T-cell.purity_filtered.txt',
#  'BLUEPRINT_SE_ge_monocyte.purity_filtered.txt',
#  'Nedelec_2016_ge_macrophage_Listeria.purity_filtered.txt',
#  'Schmiedel_2018_ge_Treg_memory.purity_filtered.txt',
#  'Schmiedel_2018_tx_B-cell_naive.purity_filtered.txt',
#  'BLUEPRINT_SE_ge_neutrophil.purity_filtered.txt.gz',
#  'Alasoo_2018_tx_macrophage_naive.purity_filtered.txt.gz',
#  'BLUEPRINT_SE_txrev_neutrophil.purity_filtered.txt.gz',
#  'Alasoo_2018_exon_macrophage_naive.purity_filtered.txt.gz',
#  'GENCORD_exon_T-cell.purity_filtered.txt.gz',
#  'Kasela_2017_microarray_T-cell_CD8.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_Th1_memory.purity_filtered.txt.gz',
#  'Quach_2016_tx_monocyte_naive.purity_filtered.txt.gz',
#  'Bossini-Castillo_2019_tx_Treg_naive.purity_filtered.txt.gz',
#  'Nedelec_2016_txrev_macrophage_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_exon_B-cell_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_CD8_T-cell_anti-CD3-CD28.purity_filtered.txt.gz',
#  'Schmiedel_2018_exon_Th1-17_memory.purity_filtered.txt.gz',
#  'Schmiedel_2018_exon_Th1_memory.purity_filtered.txt.gz',
#  'Bossini-Castillo_2019_txrev_Treg_naive.purity_filtered.txt.gz',
#  'CEDAR_microarray_B-cell_CD19.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_monocyte_naive.purity_filtered.txt.gz.tbi',
#  'Bossini-Castillo_2019_ge_Treg_naive.purity_filtered.txt.gz.tbi',
#  'Nedelec_2016_txrev_macrophage_Salmonella.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_NK-cell_naive.purity_filtered.txt.gz.tbi',
#  'Quach_2016_ge_monocyte_Pam3CSK4.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_CD4_T-cell_anti-CD3-CD28.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_tx_macrophage_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_CD8_T-cell_anti-CD3-CD28.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_CD4_T-cell_naive.purity_filtered.txt.gz.tbi',
#  'GENCORD_tx_LCL.purity_filtered.txt.gz.tbi',
#  'Nedelec_2016_ge_macrophage_naive.purity_filtered.txt.gz.tbi',
#  'Quach_2016_txrev_monocyte_naive.purity_filtered.txt.gz.tbi',
#  'GENCORD_txrev_LCL.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_Th1-17_memory.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_Th2_memory.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_txrev_macrophage_naive.purity_filtered.txt.gz.tbi',
#  'Quach_2016_ge_monocyte_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_Tfh_memory.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_Tfh_memory.purity_filtered.txt.gz.tbi',
#  'GENCORD_exon_fibroblast.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_CD4_T-cell_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_CD8_T-cell_anti-CD3-CD28.purity_filtered.txt.gz.tbi',
#  'Fairfax_2014_microarray_monocyte_LPS2.purity_filtered.txt',
#  'BLUEPRINT_PE_txrev_T-cell.purity_filtered.txt',
#  'Alasoo_2018_ge_macrophage_IFNg+Salmonella.purity_filtered.txt',
#  'GENCORD_txrev_fibroblast.purity_filtered.txt',
#  'Schmiedel_2018_tx_CD4_T-cell_naive.purity_filtered.txt',
#  'Schmiedel_2018_tx_Th1_memory.purity_filtered.txt',
#  'Schmiedel_2018_txrev_NK-cell_naive.purity_filtered.txt',
#  'Nedelec_2016_txrev_macrophage_Listeria.purity_filtered.txt',
#  'Schmiedel_2018_ge_Th1-17_memory.purity_filtered.txt',
#  'Schmiedel_2018_tx_Treg_memory.purity_filtered.txt',
#  'Schmiedel_2018_ge_Treg_naive.purity_filtered.txt.gz',
#  'Alasoo_2018_txrev_macrophage_IFNg.purity_filtered.txt',
#  'Quach_2016_tx_monocyte_R848.purity_filtered.txt',
#  'Schmiedel_2018_tx_monocyte_CD16_naive.purity_filtered.txt',
#  'Schmiedel_2018_txrev_Treg_memory.purity_filtered.txt',
#  'Alasoo_2018_exon_macrophage_IFNg.purity_filtered.txt',
#  'Bossini-Castillo_2019_tx_Treg_naive.purity_filtered.txt',
#  'CEDAR_microarray_transverse_colon.purity_filtered.txt',
#  'Schmiedel_2018_txrev_CD8_T-cell_anti-CD3-CD28.purity_filtered.txt.gz',
#  'BLUEPRINT_PE_exon_T-cell.purity_filtered.txt.gz',
#  'Alasoo_2018_ge_macrophage_IFNg.purity_filtered.txt.gz',
#  'Fairfax_2014_microarray_monocyte_naive.purity_filtered.txt.gz',
#  'BLUEPRINT_SE_ge_monocyte.purity_filtered.txt.gz',
#  'CEDAR_microarray_transverse_colon.purity_filtered.txt.gz',
#  'Quach_2016_ge_monocyte_LPS.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_Th1-17_memory.purity_filtered.txt.gz',
#  'GENCORD_tx_LCL.purity_filtered.txt.gz',
#  'Nedelec_2016_exon_macrophage_naive.purity_filtered.txt.gz',
#  'Alasoo_2018_exon_macrophage_Salmonella.purity_filtered.txt.gz',
#  'Alasoo_2018_tx_macrophage_IFNg.purity_filtered.txt.gz',
#  'BLUEPRINT_PE_tx_T-cell.purity_filtered.txt.gz',
#  'Schmiedel_2018_exon_Treg_naive.purity_filtered.txt.gz',
#  'Alasoo_2018_ge_macrophage_IFNg+Salmonella.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_Th1_memory.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_NK-cell_naive.purity_filtered.txt.gz.tbi',
#  'Fairfax_2014_microarray_monocyte_LPS24.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_txrev_macrophage_IFNg+Salmonella.purity_filtered.txt.gz.tbi',
#  'Quach_2016_txrev_monocyte_IAV.purity_filtered.txt.gz.tbi',
#  'Quach_2016_ge_monocyte_IAV.purity_filtered.txt.gz.tbi',
#  'Quach_2016_txrev_monocyte_Pam3CSK4.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_Th17_memory.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_Tfh_memory.purity_filtered.txt.gz.tbi',
#  'Quach_2016_tx_monocyte_R848.purity_filtered.txt.gz.tbi',
#  'Nedelec_2016_ge_macrophage_Listeria.purity_filtered.txt.gz.tbi',
#  'Nedelec_2016_tx_macrophage_Salmonella.purity_filtered.txt.gz.tbi',
#  'Fairfax_2014_microarray_monocyte_IFN24.purity_filtered.txt',
#  'Alasoo_2018_txrev_macrophage_naive.purity_filtered.txt',
#  'Schmiedel_2018_tx_Th1-17_memory.purity_filtered.txt',
#  'CEDAR_microarray_monocyte_CD14.purity_filtered.txt',
#  'Bossini-Castillo_2019_ge_Treg_naive.purity_filtered.txt',
#  'Kasela_2017_microarray_T-cell_CD4.purity_filtered.txt',
#  'Nedelec_2016_exon_macrophage_naive.purity_filtered.txt',
#  'Schmiedel_2018_exon_B-cell_naive.purity_filtered.txt',
#  'Schmiedel_2018_tx_monocyte_naive.purity_filtered.txt',
#  'Schmiedel_2018_txrev_Treg_naive.purity_filtered.txt',
#  'Schmiedel_2018_tx_Tfh_memory.purity_filtered.txt',
#  'Fairfax_2012_microarray_B-cell_CD19.purity_filtered.txt.gz',
#  'CEDAR_microarray_neutrophil_CD15.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_Th17_memory.purity_filtered.txt.gz',
#  'Alasoo_2018_tx_macrophage_IFNg.purity_filtered.txt',
#  'Schmiedel_2018_ge_B-cell_naive.purity_filtered.txt.gz',
#  'Alasoo_2018_txrev_macrophage_IFNg+Salmonella.purity_filtered.txt.gz',
#  'GENCORD_txrev_LCL.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_Th1-17_memory.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_CD8_T-cell_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_Th1-17_memory.purity_filtered.txt.gz',
#  'Alasoo_2018_txrev_macrophage_naive.purity_filtered.txt.gz',
#  'Quach_2016_exon_monocyte_LPS.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_Tfh_memory.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_Treg_naive.purity_filtered.txt.gz',
#  'GENCORD_ge_T-cell.purity_filtered.txt.gz',
#  'Quach_2016_txrev_monocyte_IAV.purity_filtered.txt.gz',
#  'Quach_2016_ge_monocyte_IAV.purity_filtered.txt.gz',
#  'BLUEPRINT_SE_txrev_monocyte.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_CD8_T-cell_naive.purity_filtered.txt.gz.tbi',
#  'GENCORD_tx_fibroblast.purity_filtered.txt.gz.tbi',
#  'Nedelec_2016_txrev_macrophage_Listeria.purity_filtered.txt.gz.tbi',
#  'Bossini-Castillo_2019_exon_Treg_naive.purity_filtered.txt.gz.tbi',
#  'GENCORD_ge_fibroblast.purity_filtered.txt.gz.tbi',
#  'CEDAR_microarray_monocyte_CD14.purity_filtered.txt.gz.tbi',
#  'Quach_2016_tx_monocyte_Pam3CSK4.purity_filtered.txt.gz.tbi',
#  'Nedelec_2016_txrev_macrophage_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_B-cell_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_Th1-17_memory.purity_filtered.txt.gz.tbi',
#  'Bossini-Castillo_2019_txrev_Treg_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_CD8_T-cell_anti-CD3-CD28.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_ge_macrophage_IFNg.purity_filtered.txt.gz.tbi',
#  'Fairfax_2014_microarray_monocyte_naive.purity_filtered.txt.gz.tbi',
#  'Nedelec_2016_exon_macrophage_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_monocyte_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_NK-cell_naive.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_tx_macrophage_IFNg+Salmonella.purity_filtered.txt.gz.tbi',
#  'CEDAR_microarray_neutrophil_CD15.purity_filtered.txt.gz.tbi',
#  'BLUEPRINT_PE_txrev_T-cell.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_CD8_T-cell_naive.purity_filtered.txt.gz.tbi',
#  'GENCORD_ge_T-cell.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_txrev_macrophage_Salmonella.purity_filtered.txt.gz.tbi',
#  'Quach_2016_exon_monocyte_R848.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_Th2_memory.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_NK-cell_naive.purity_filtered.txt.gz.tbi',
#  'CEDAR_microarray_rectum.purity_filtered.txt.gz.tbi',
#  'Quach_2016_txrev_monocyte_LPS.purity_filtered.txt.gz.tbi',
#  'GENCORD_exon_LCL.purity_filtered.txt',
#  'Nedelec_2016_ge_macrophage_naive.purity_filtered.txt',
#  'CEDAR_microarray_rectum.purity_filtered.txt',
#  'Nedelec_2016_tx_macrophage_Salmonella.purity_filtered.txt',
#  'Schmiedel_2018_tx_NK-cell_naive.purity_filtered.txt',
#  'Alasoo_2018_ge_macrophage_Salmonella.purity_filtered.txt.gz',
#  'Alasoo_2018_txrev_macrophage_Salmonella.purity_filtered.txt',
#  'Quach_2016_ge_monocyte_IAV.purity_filtered.txt',
#  'Schmiedel_2018_exon_Treg_memory.purity_filtered.txt',
#  'Schmiedel_2018_txrev_monocyte_CD16_naive.purity_filtered.txt',
#  'Quach_2016_exon_monocyte_R848.purity_filtered.txt.gz',
#  'BLUEPRINT_SE_txrev_monocyte.purity_filtered.txt',
#  'Bossini-Castillo_2019_txrev_Treg_naive.purity_filtered.txt',
#  'CEDAR_microarray_B-cell_CD19.purity_filtered.txt',
#  'CEDAR_microarray_ileum.purity_filtered.txt',
#  'Quach_2016_exon_monocyte_naive.purity_filtered.txt',
#  'Quach_2016_txrev_monocyte_naive.purity_filtered.txt',
#  'Quach_2016_txrev_monocyte_Pam3CSK4.purity_filtered.txt',
#  'Schmiedel_2018_ge_monocyte_CD16_naive.purity_filtered.txt',
#  'Schmiedel_2018_tx_Th2_memory.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_Th2_memory.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_B-cell_naive.purity_filtered.txt.gz',
#  'BLUEPRINT_PE_ge_T-cell.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_Treg_memory.purity_filtered.txt.gz',
#  'GENCORD_exon_fibroblast.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_CD4_T-cell_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_Th1_memory.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_NK-cell_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_Tfh_memory.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_Tfh_memory.purity_filtered.txt.gz',
#  'GENCORD_tx_T-cell.purity_filtered.txt.gz',
#  'Schmiedel_2018_exon_Th2_memory.purity_filtered.txt.gz',
#  'Nedelec_2016_tx_macrophage_naive.purity_filtered.txt.gz.tbi',
#  'Nedelec_2016_ge_macrophage_Salmonella.purity_filtered.txt.gz.tbi',
#  'Nedelec_2016_tx_macrophage_Listeria.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_Treg_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_CD8_T-cell_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_Treg_memory.purity_filtered.txt.gz.tbi',
#  'Quach_2016_ge_monocyte_LPS.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_tx_macrophage_IFNg.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_Th1-17_memory.purity_filtered.txt.gz.tbi',
#  'Quach_2016_exon_monocyte_LPS.purity_filtered.txt.gz.tbi',
#  'Nedelec_2016_exon_macrophage_Salmonella.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_monocyte_CD16_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_Treg_memory.purity_filtered.txt.gz.tbi',
#  'Fairfax_2014_microarray_monocyte_LPS2.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_Th1_memory.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_Th1_memory.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_CD4_T-cell_naive.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_exon_macrophage_IFNg.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_Treg_memory.purity_filtered.txt.gz.tbi',
#  'GENCORD_txrev_fibroblast.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_Th17_memory.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_B-cell_naive.purity_filtered.txt',
#  'Schmiedel_2018_ge_CD8_T-cell_naive.purity_filtered.txt',
#  'CEDAR_microarray_platelet.purity_filtered.txt',
#  'Schmiedel_2018_tx_monocyte_CD16_naive.purity_filtered.txt.gz',
#  'Quach_2016_txrev_monocyte_LPS.purity_filtered.txt',
#  'Schmiedel_2018_txrev_Th1_memory.purity_filtered.txt.gz',
#  'Nedelec_2016_exon_macrophage_Salmonella.purity_filtered.txt',
#  'Schmiedel_2018_exon_CD8_T-cell_naive.purity_filtered.txt',
#  'Schmiedel_2018_exon_CD4_T-cell_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_CD4_T-cell_anti-CD3-CD28.purity_filtered.txt',
#  'Alasoo_2018_ge_macrophage_IFNg.purity_filtered.txt',
#  'Fairfax_2014_microarray_monocyte_LPS24.purity_filtered.txt',
#  'Quach_2016_txrev_monocyte_LPS.purity_filtered.txt.gz',
#  'GENCORD_exon_LCL.purity_filtered.txt.gz',
#  'Quach_2016_tx_monocyte_IAV.purity_filtered.txt',
#  'Schmiedel_2018_txrev_CD8_T-cell_naive.purity_filtered.txt',
#  'Alasoo_2018_exon_macrophage_IFNg.purity_filtered.txt.gz',
#  'Gilchrist_2021_microarray_NK-cell_naive.purity_filtered.txt',
#  'Nedelec_2016_tx_macrophage_Listeria.purity_filtered.txt',
#  'Schmiedel_2018_ge_Th2_memory.purity_filtered.txt',
#  'Schmiedel_2018_exon_CD8_T-cell_anti-CD3-CD28.purity_filtered.txt',
#  'Schmiedel_2018_ge_CD8_T-cell_anti-CD3-CD28.purity_filtered.txt.gz',
#  'Quach_2016_exon_monocyte_Pam3CSK4.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_Treg_memory.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_B-cell_naive.purity_filtered.txt',
#  'GENCORD_txrev_fibroblast.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_Th17_memory.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_Th1_memory.purity_filtered.txt',
#  'Alasoo_2018_exon_macrophage_naive.purity_filtered.txt',
#  'Schmiedel_2018_ge_CD8_T-cell_anti-CD3-CD28.purity_filtered.txt',
#  'Nedelec_2016_ge_macrophage_Listeria.purity_filtered.txt.gz',
#  'CEDAR_microarray_T-cell_CD4.purity_filtered.txt.gz',
#  'Nedelec_2016_tx_macrophage_Salmonella.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_monocyte_CD16_naive.purity_filtered.txt.gz',
#  'BLUEPRINT_SE_tx_neutrophil.purity_filtered.txt.gz',
#  'Naranbhai_2015_microarray_neutrophil_CD16.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_CD4_T-cell_anti-CD3-CD28.purity_filtered.txt.gz.tbi',
#  'CEDAR_microarray_ileum.purity_filtered.txt.gz.tbi',
#  'BLUEPRINT_SE_txrev_neutrophil.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_exon_macrophage_Salmonella.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_Th17_memory.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_B-cell_naive.purity_filtered.txt.gz.tbi',
#  'BLUEPRINT_PE_ge_T-cell.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_Tfh_memory.purity_filtered.txt.gz.tbi',
#  'GENCORD_ge_LCL.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_monocyte_CD16_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_monocyte_CD16_naive.purity_filtered.txt.gz.tbi',
#  'Fairfax_2014_microarray_monocyte_LPS2.purity_filtered.txt.gz',
#  'GENCORD_txrev_T-cell.purity_filtered.txt.gz',
#  'Schmiedel_2018_exon_Treg_naive.purity_filtered.txt',
#  'Schmiedel_2018_exon_monocyte_CD16_naive.purity_filtered.txt.gz',
#  'CEDAR_microarray_platelet.purity_filtered.txt.gz',
#  'Schmiedel_2018_exon_CD4_T-cell_anti-CD3-CD28.purity_filtered.txt',
#  'GENCORD_ge_LCL.purity_filtered.txt',
#  'Quach_2016_txrev_monocyte_IAV.purity_filtered.txt',
#  'GENCORD_ge_T-cell.purity_filtered.txt',
#  'Schmiedel_2018_exon_monocyte_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_monocyte_naive.purity_filtered.txt',
#  'Quach_2016_ge_monocyte_Pam3CSK4.purity_filtered.txt',
#  'Quach_2016_tx_monocyte_LPS.purity_filtered.txt',
#  'Schmiedel_2018_ge_Th17_memory.purity_filtered.txt.gz',
#  'Schmiedel_2018_exon_NK-cell_naive.purity_filtered.txt',
#  'Schmiedel_2018_exon_Th1_memory.purity_filtered.txt',
#  'Schmiedel_2018_txrev_monocyte_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_NK-cell_naive.purity_filtered.txt',
#  'Quach_2016_tx_monocyte_R848.purity_filtered.txt.gz',
#  'Nedelec_2016_txrev_macrophage_Salmonella.purity_filtered.txt',
#  'CEDAR_microarray_rectum.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_monocyte_CD16_naive.purity_filtered.txt.gz',
#  'Nedelec_2016_exon_macrophage_Salmonella.purity_filtered.txt.gz',
#  'BLUEPRINT_PE_tx_T-cell.purity_filtered.txt',
#  'GENCORD_ge_LCL.purity_filtered.txt.gz',
#  'BLUEPRINT_SE_tx_monocyte.purity_filtered.txt',
#  'Schmiedel_2018_exon_Tfh_memory.purity_filtered.txt.gz',
#  'Nedelec_2016_exon_macrophage_Listeria.purity_filtered.txt.gz',
#  'CEDAR_microarray_T-cell_CD4.purity_filtered.txt',
#  'Schmiedel_2018_exon_Th1-17_memory.purity_filtered.txt',
#  'BLUEPRINT_SE_tx_neutrophil.purity_filtered.txt',
#  'CEDAR_microarray_T-cell_CD8.purity_filtered.txt',
#  'Quach_2016_tx_monocyte_IAV.purity_filtered.txt.gz',
#  'Alasoo_2018_exon_macrophage_IFNg+Salmonella.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_CD8_T-cell_naive.purity_filtered.txt.gz.tbi',
#  'Quach_2016_tx_monocyte_LPS.purity_filtered.txt.gz.tbi',
#  'BLUEPRINT_SE_ge_neutrophil.purity_filtered.txt.gz.tbi',
#  'Bossini-Castillo_2019_tx_Treg_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_CD4_T-cell_anti-CD3-CD28.purity_filtered.txt.gz.tbi',
#  'BLUEPRINT_PE_exon_T-cell.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_ge_macrophage_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_Treg_naive.purity_filtered.txt.gz.tbi',
#  'BLUEPRINT_PE_tx_T-cell.purity_filtered.txt.gz.tbi',
#  'CEDAR_microarray_T-cell_CD8.purity_filtered.txt.gz.tbi',
#  'Fairfax_2012_microarray_B-cell_CD19.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_Th17_memory.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_CD4_T-cell_anti-CD3-CD28.purity_filtered.txt.gz.tbi',
#  'GENCORD_txrev_T-cell.purity_filtered.txt.gz.tbi',
#  'Nedelec_2016_exon_macrophage_Listeria.purity_filtered.txt.gz.tbi',
#  'CEDAR_microarray_platelet.purity_filtered.txt.gz.tbi',
#  'Quach_2016_tx_monocyte_IAV.purity_filtered.txt.gz.tbi',
#  'GENCORD_tx_T-cell.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_monocyte_naive.purity_filtered.txt.gz.tbi',
#  'GENCORD_exon_LCL.purity_filtered.txt.gz.tbi',
#  'CEDAR_microarray_T-cell_CD4.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_ge_macrophage_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_CD4_T-cell_anti-CD3-CD28.purity_filtered.txt.gz',
#  'BLUEPRINT_SE_exon_monocyte.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_Th2_memory.purity_filtered.txt',
#  'Schmiedel_2018_exon_CD8_T-cell_naive.purity_filtered.txt.gz',
#  'GENCORD_tx_fibroblast.purity_filtered.txt',
#  'Schmiedel_2018_ge_Tfh_memory.purity_filtered.txt',
#  'Alasoo_2018_tx_macrophage_Salmonella.purity_filtered.txt',
#  'Alasoo_2018_ge_macrophage_naive.purity_filtered.txt',
#  'Schmiedel_2018_ge_monocyte_naive.purity_filtered.txt',
#  'Schmiedel_2018_txrev_Tfh_memory.purity_filtered.txt',
#  'GENCORD_txrev_LCL.purity_filtered.txt',
#  'Schmiedel_2018_txrev_Treg_naive.purity_filtered.txt.gz',
#  'CEDAR_microarray_T-cell_CD8.purity_filtered.txt.gz',
#  'Bossini-Castillo_2019_exon_Treg_naive.purity_filtered.txt',
#  'Quach_2016_txrev_monocyte_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_Th1_memory.purity_filtered.txt',
#  'Schmiedel_2018_exon_NK-cell_naive.purity_filtered.txt.gz',
#  'GENCORD_exon_fibroblast.purity_filtered.txt',
#  'Schmiedel_2018_exon_CD8_T-cell_anti-CD3-CD28.purity_filtered.txt.gz',
#  'BLUEPRINT_SE_exon_neutrophil.purity_filtered.txt.gz.tbi',
#  'Quach_2016_exon_monocyte_Pam3CSK4.purity_filtered.txt',
#  'Schmiedel_2018_ge_CD4_T-cell_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_Treg_memory.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_CD8_T-cell_naive.purity_filtered.txt',
#  'Schmiedel_2018_ge_NK-cell_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_CD4_T-cell_naive.purity_filtered.txt.gz',
#  'Quach_2016_tx_monocyte_naive.purity_filtered.txt',
#  'Nedelec_2016_ge_macrophage_naive.purity_filtered.txt.gz',
#  'Quach_2016_txrev_monocyte_R848.purity_filtered.txt',
#  'Schmiedel_2018_tx_monocyte_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_Th1-17_memory.purity_filtered.txt',
#  'Alasoo_2018_txrev_macrophage_IFNg.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_CD8_T-cell_anti-CD3-CD28.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_CD4_T-cell_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_exon_Treg_memory.purity_filtered.txt.gz.tbi',
#  'BLUEPRINT_SE_txrev_monocyte.purity_filtered.txt.gz.tbi',
#  'BLUEPRINT_SE_exon_monocyte.purity_filtered.txt',
#  'Quach_2016_ge_monocyte_naive.purity_filtered.txt',
#  'Quach_2016_exon_monocyte_LPS.purity_filtered.txt',
#  'Alasoo_2018_exon_macrophage_Salmonella.purity_filtered.txt',
#  'Schmiedel_2018_txrev_Th2_memory.purity_filtered.txt.gz',
#  'Alasoo_2018_tx_macrophage_Salmonella.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_CD4_T-cell_anti-CD3-CD28.purity_filtered.txt.gz',
#  'Quach_2016_txrev_monocyte_Pam3CSK4.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_CD4_T-cell_anti-CD3-CD28.purity_filtered.txt',
#  'GENCORD_tx_T-cell.purity_filtered.txt',
#  'Quach_2016_tx_monocyte_Pam3CSK4.purity_filtered.txt',
#  'Quach_2016_ge_monocyte_R848.purity_filtered.txt.gz.tbi',
#  'Nedelec_2016_txrev_macrophage_naive.purity_filtered.txt',
#  'GENCORD_tx_LCL.purity_filtered.txt',
#  'Quach_2016_exon_monocyte_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_B-cell_naive.purity_filtered.txt.gz',
#  'Alasoo_2018_txrev_macrophage_Salmonella.purity_filtered.txt.gz',
#  'Alasoo_2018_tx_macrophage_IFNg+Salmonella.purity_filtered.txt.gz',
#  'Schmiedel_2018_exon_Th17_memory.purity_filtered.txt.gz',
#  'Quach_2016_ge_monocyte_LPS.purity_filtered.txt',
#  'BLUEPRINT_PE_txrev_T-cell.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_CD4_T-cell_naive.purity_filtered.txt',
#  'Schmiedel_2018_tx_CD8_T-cell_anti-CD3-CD28.purity_filtered.txt',
#  'GENCORD_ge_fibroblast.purity_filtered.txt',
#  'Fairfax_2014_microarray_monocyte_LPS24.purity_filtered.txt.gz',
#  'Schmiedel_2018_exon_Th2_memory.purity_filtered.txt',
#  'Naranbhai_2015_microarray_neutrophil_CD16.purity_filtered.txt',
#  'Gilchrist_2021_microarray_NK-cell_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_Treg_naive.purity_filtered.txt',
#  'Quach_2016_ge_monocyte_naive.purity_filtered.txt.gz',
#  'Schmiedel_2018_exon_Treg_memory.purity_filtered.txt.gz',
#  'Fairfax_2014_microarray_monocyte_IFN24.purity_filtered.txt.gz',
#  'Kasela_2017_microarray_T-cell_CD4.purity_filtered.txt.gz.tbi',
#  'Kasela_2017_microarray_T-cell_CD8.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_Th1_memory.purity_filtered.txt.gz.tbi',
#  'CEDAR_microarray_B-cell_CD19.purity_filtered.txt.gz.tbi',
#  'CEDAR_microarray_transverse_colon.purity_filtered.txt.gz.tbi',
#  'Gilchrist_2021_microarray_NK-cell_naive.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_Treg_naive.purity_filtered.txt.gz.tbi',
#  'Quach_2016_exon_monocyte_naive.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_ge_macrophage_Salmonella.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_B-cell_naive.purity_filtered.txt.gz.tbi',
#  'Quach_2016_exon_monocyte_Pam3CSK4.purity_filtered.txt.gz.tbi',
#  'BLUEPRINT_SE_tx_neutrophil.purity_filtered.txt.gz.tbi',
#  'Kasela_2017_microarray_T-cell_CD4.purity_filtered.txt.gz',
#  'Quach_2016_exon_monocyte_R848.purity_filtered.txt',
#  'Alasoo_2018_tx_macrophage_IFNg+Salmonella.purity_filtered.txt',
#  'Naranbhai_2015_microarray_neutrophil_CD16.purity_filtered.txt.gz',
#  'Schmiedel_2018_exon_Treg_naive.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_txrev_macrophage_IFNg.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_Th17_memory.purity_filtered.txt',
#  'Quach_2016_exon_monocyte_IAV.purity_filtered.txt.gz',
#  'BLUEPRINT_SE_tx_monocyte.purity_filtered.txt.gz',
#  'Alasoo_2018_ge_macrophage_Salmonella.purity_filtered.txt',
#  'Schmiedel_2018_exon_Tfh_memory.purity_filtered.txt',
#  'Nedelec_2016_exon_macrophage_Listeria.purity_filtered.txt',
#  'Alasoo_2018_exon_macrophage_naive.purity_filtered.txt.gz.tbi',
#  'CEDAR_microarray_ileum.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_CD8_T-cell_anti-CD3-CD28.purity_filtered.txt',
#  'Quach_2016_txrev_monocyte_R848.purity_filtered.txt.gz',
#  'Schmiedel_2018_ge_Th17_memory.purity_filtered.txt',
#  'Fairfax_2012_microarray_B-cell_CD19.purity_filtered.txt',
#  'Quach_2016_txrev_monocyte_R848.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_tx_B-cell_naive.purity_filtered.txt.gz.tbi',
#  'Alasoo_2018_tx_macrophage_Salmonella.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_ge_monocyte_naive.purity_filtered.txt.gz',
#  'GENCORD_exon_T-cell.purity_filtered.txt.gz.tbi',
#  'Schmiedel_2018_txrev_CD8_T-cell_naive.purity_filtered.txt.gz',
#  'BLUEPRINT_SE_exon_neutrophil.purity_filtered.txt.gz',
#  'BLUEPRINT_SE_exon_monocyte.purity_filtered.txt.gz.tbi',
#  'Nedelec_2016_ge_macrophage_Salmonella.purity_filtered.txt.gz',
#  'Schmiedel_2018_txrev_CD4_T-cell_anti-CD3-CD28.purity_filtered.txt',
#  'BLUEPRINT_SE_exon_neutrophil.purity_filtered.txt',
#  'GENCORD_tx_fibroblast.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_CD4_T-cell_anti-CD3-CD28.purity_filtered.txt.gz',
#  'Schmiedel_2018_tx_monocyte_CD16_naive.purity_filtered.txt.gz.tbi']

# %%
# Now need to tabix index all of the files in the curated crediblesets directory

files = [out_dir + i for i in os.listdir(out_dir) if i.split(".")[-1]=="gz"]

for file in files:
    command = "tabix -c m -s 3 -b 4 -e 4 "
    command +=file
    os.system(command)

# %%
x.chromosome = x.chromosome.astype(str)

# %%
name = [i for i in files if i.split(".")[-1]=="txt"][0]

name = name.split("/")[-1]
name = "sorted_" + name

name = out_dir + name

# %%
len(files)
# Out:
# 154
